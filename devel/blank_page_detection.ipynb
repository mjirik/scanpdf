# %%
# %pylab inline

import sys
import glob
import os.path as op
import shutil
# from matplotlib import pyplot as plt
import scipy.misc
# import skimage.transform
import skimage.io
import skimage.color
import tesserocr
from PIL import Image
import re
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\Users\miros\Miniconda3\envs\scanpdf\lib\site-packages\IPython\core\magics\pylab.py:160: UserWarning: pylab import has clobbered these variables: ['hist']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
path = r"C:/Users/miros/Dokumenty/Scanned Documents/Šumavan zima 2018"

# %%
head, teil = op.split(path)
jpgs_path = op.join(head, teil + " - sorted")
fns = glob.glob(op.join(jpgs_path, "*"))

# %%
im = plt.imread(fns[0])
img = skimage.color.rgb2gray(im)
hist = np.histogram(img[img < 0.9])
plt.plot(hist[1][1:], hist[0])
plt.figure(figsize=(15, 10))
plt.imshow(im)

# %%
im = plt.imread(fns[9])
img = im[:, :, 0]
hist = np.histogram(img[img < 200])
plt.plot(hist[1][1:], hist[0])
plt.figure(figsize=(15, 10))
plt.imshow(im)

# %%
im = plt.imread(fns[0])
img = skimage.color.rgb2gray(im)
np.sum(img < 0.9) / np.prod(img.shape)
# Out:
# 0.08022924322554272

# %%
im = plt.imread(fns[9])
img = skimage.color.rgb2gray(im)
np.sum(img < 0.9) / np.prod(img.shape)
# Out:
# 0.00017764156213281168
